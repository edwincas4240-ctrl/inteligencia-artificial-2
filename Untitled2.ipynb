# %% [markdown]
# <a href="https://colab.research.google.com/github/edwincas4240-ctrl/inteligencia-artificial-2/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Ecosistema TecnológicoComponentes clave:Python Data StackScikit-learn SuiteGoogle Colab (Cloud)Git y GitHub EnterpriseDiagrama visual: Muestra la interacción de Google Colab en el centro, conectado con Python, el Servidor y Git.2. Preparación de Datos (Arquitectura de Datos)Introducción: Sección orientada al flujo y canalización de los datos desde su recolección hasta su preparación previa al entrenamiento.Diagrama: Representa un pipeline de datos donde la información fluye a través de filtros, transformaciones y almacenamiento intermedio.3. Fuga de Datos (Data Leakage)Definición: Se define como la filtración inadvertida de información del conjunto de prueba (test set) al conjunto de entrenamiento (training set), lo que invalida el modelo.Impacto: Se señala en la interfaz como un fatal error.4. Etapas de Preprocesamiento de DatosImputación: Tratamiento y rellenado de valores nulos o faltantes.Escalamiento: Normalización de escalas numéricas de las variables.Reducción: Compresión dimensional de las variables.Clasificador: Estimador final y predicción algorítmica.5. Modelos Supervisados (Clasificación Predictiva)Sección 3 de la presentación: Enfocada en modelos supervisados.Tipos principales:Clasificación: Separación de datos en categorías discretas.Regresión: Predicción de valores continuos sobre una tendencia.6. Truco del Kernel (Kernel Trick)Función: Función que proyecta datos a dimensiones superiores para resolver problemas no lineales en Máquinas de Vectores de Soporte (SVM).Gráfico: Muestra cómo datos mezclados/complejos se separan al ser transformados geométricamente.7. Técnicas de Ensemble (Bagging vs. Boosting)Bagging: Reduce la varianza utilizando múltiples árboles de decisión entrenados en paralelo (e.g., Random Forest).Boosting: Reduce el sesgo corrigiendo los errores de manera iterativa/secuencial (representado con un cohete que ajusta su trayectoria).8. Importancia de Características (Feature Importance)Gráfico de barras: Representa la importancia relativa (%) de las variables extraídas por el modelo:Edad: Mayor relevancia (~43%).Ingresos: Importancia media (~33%).Historial: Menor relevancia (~22%).9. IA No Supervisada (Buscando lo Desconocido)Sección 4 de la presentación: Enfoque en algoritmos que encuentran patrones ocultos o estructuras en datos no etiquetados.10. Algoritmos No SupervisadosResumen en tabla de los algoritmos explicados en la diapositiva:AlgoritmoFunciónAplicaciónK-MeansAgrupamiento (Clustering)Segmentación de usuarios/clientesDBSCANBasado en DensidadAnálisis DemográficoIsolation ForestDetección de AnomalíasDetección de Fraude
